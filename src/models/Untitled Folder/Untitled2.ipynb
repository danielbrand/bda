# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
data_path = "/Users/danielbrand/Documents/Ideen/Big Data Analytics Platform Prototype/telco_final.csv"

# %%
data = pd.read_csv(data_path)

# %%
data.describe()
# Out:
#            is_male  is_senior_citizen  has_partner  has_dependents  \
# count  7032.000000        7032.000000  7032.000000     7032.000000
# mean      0.504693           0.162400     0.482509        0.298493
# std       0.500014           0.368844     0.499729        0.457629
# min       0.000000           0.000000     0.000000        0.000000
# 25%       0.000000           0.000000     0.000000        0.000000
# 50%       1.000000           0.000000     0.000000        0.000000
# 75%       1.000000           0.000000     1.000000        1.000000
# max       1.000000           1.000000     1.000000        1.000000
#
#             tenure  has_phone_service  has_paperless_billing  monthly_charges  \
# count  7032.000000        7032.000000            7032.000000      7032.000000
# mean     32.421786           0.903299               0.592719        64.798208
# std      24.545260           0.295571               0.491363        30.085974
# min       1.000000           0.000000               0.000000        18.250000
# 25%       9.000000           1.000000               0.000000        35.587500
# 50%      29.000000           1.000000               1.000000        70.350000
# 75%      55.000000           1.000000               1.000000        89.862500
# max      72.000000           1.000000               1.000000       118.750000
#
#        total_charges  has_multiple_lines_No             ...               \
# count    7032.000000            7032.000000             ...
# mean     2283.300441               0.481371             ...
# std      2266.771362               0.499688             ...
# min        18.800000               0.000000             ...
# 25%       401.450000               0.000000             ...
# 50%      1397.475000               0.000000             ...
# 75%      3794.737500               1.000000             ...
# max      8684.800000               1.000000             ...
#
#        has_streaming_movies_No  has_streaming_movies_No internet service  \
# count              7032.000000                               7032.000000
# mean                  0.395478                                  0.216155
# std                   0.488988                                  0.411650
# min                   0.000000                                  0.000000
# 25%                   0.000000                                  0.000000
# 50%                   0.000000                                  0.000000
# 75%                   1.000000                                  0.000000
# max                   1.000000                                  1.000000
#
#        has_streaming_movies_Yes  contract_Month-to-month  contract_One year  \
# count               7032.000000              7032.000000        7032.000000
# mean                   0.388367                 0.551052           0.209329
# std                    0.487414                 0.497422           0.406858
# min                    0.000000                 0.000000           0.000000
# 25%                    0.000000                 0.000000           0.000000
# 50%                    0.000000                 1.000000           0.000000
# 75%                    1.000000                 1.000000           0.000000
# max                    1.000000                 1.000000           1.000000
#
#        contract_Two year  payment_method_Bank transfer (automatic)  \
# count        7032.000000                               7032.000000
# mean            0.239619                                  0.219283
# std             0.426881                                  0.413790
# min             0.000000                                  0.000000
# 25%             0.000000                                  0.000000
# 50%             0.000000                                  0.000000
# 75%             0.000000                                  0.000000
# max             1.000000                                  1.000000
#
#        payment_method_Credit card (automatic)  \
# count                             7032.000000
# mean                                 0.216297
# std                                  0.411748
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  1.000000
#
#        payment_method_Electronic check  payment_method_Mailed check
# count                      7032.000000                  7032.000000
# mean                          0.336320                     0.228100
# std                           0.472483                     0.419637
# min                           0.000000                     0.000000
# 25%                           0.000000                     0.000000
# 50%                           0.000000                     0.000000
# 75%                           1.000000                     0.000000
# max                           1.000000                     1.000000
#
# [8 rows x 40 columns]

# %%
sns.set()
data.hist("tenure")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a37f320>]],
#       dtype=object)

# %%
data["churn"].value_counts()
# Out:
# No     5163
# Yes    1869
# Name: churn, dtype: int64

# %%
print(len(data.columns))
# Out:
# 41

# %%
print(len(data.index))
# Out:
# 7032

# %%
data.shape
# Out:
# (7032, 41)

# %%
X = data.drop("churn", axis=1)
y = data["churn"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
print(rfc.score(X_test, y_test))
# Out:
# 0.7770193401592719
